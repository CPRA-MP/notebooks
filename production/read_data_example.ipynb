# %%
from cpra.mp.data import read_data

# %%
lf = read_data(variable="sal", grid="hydro_compartment_v001", time_unit="annual", model_group_id=500, scenario_id=8, aggregate_type="mean")
lf.collect()
# Out:
# shape: (52, 1_665)
# ┌──────────┬────────────────────────┬───────────┬────────────────┬───┬────────┬──────┬──────┬──────┐
# │ variable ┆ grid                   ┆ time_unit ┆ model_group_id ┆ … ┆ 1654   ┆ 1655 ┆ 1656 ┆ 1657 │
# │ ---      ┆ ---                    ┆ ---       ┆ ---            ┆   ┆ ---    ┆ ---  ┆ ---  ┆ ---  │
# │ str      ┆ str                    ┆ str       ┆ i32            ┆   ┆ f32    ┆ f32  ┆ f32  ┆ f32  │
# ╞══════════╪════════════════════════╪═══════════╪════════════════╪═══╪════════╪══════╪══════╪══════╡
# │ sal      ┆ hydro_compartment_v001 ┆ annual    ┆ 500            ┆ … ┆ 0.2826 ┆ 0.0  ┆ 0.0  ┆ 0.0  │
# │ sal      ┆ hydro_compartment_v001 ┆ annual    ┆ 500            ┆ … ┆ 0.2291 ┆ 0.0  ┆ 0.0  ┆ 0.0  │
# │ sal      ┆ hydro_compartment_v001 ┆ annual    ┆ 500            ┆ … ┆ 0.2952 ┆ 0.0  ┆ 0.0  ┆ 0.0  │
# │ sal      ┆ hydro_compartment_v001 ┆ annual    ┆ 500            ┆ … ┆ 0.2497 ┆ 0.0  ┆ 0.0  ┆ 0.0  │
# ...

# %%
lf = read_data(variable="sal", grid="hydro_compartment_v001", time_unit="annual", model_group_id=500, scenario_id=7, aggregate_type="mean")
lf.collect()
# Out:
# shape: (52, 1_665)
# ┌──────────┬────────────────────────┬───────────┬────────────────┬───┬────────┬──────┬──────┬──────┐
# │ variable ┆ grid                   ┆ time_unit ┆ model_group_id ┆ … ┆ 1654   ┆ 1655 ┆ 1656 ┆ 1657 │
# │ ---      ┆ ---                    ┆ ---       ┆ ---            ┆   ┆ ---    ┆ ---  ┆ ---  ┆ ---  │
# │ str      ┆ str                    ┆ str       ┆ i32            ┆   ┆ f32    ┆ f32  ┆ f32  ┆ f32  │
# ╞══════════╪════════════════════════╪═══════════╪════════════════╪═══╪════════╪══════╪══════╪══════╡
# │ sal      ┆ hydro_compartment_v001 ┆ annual    ┆ 500            ┆ … ┆ 0.2826 ┆ 0.0  ┆ 0.0  ┆ 0.0  │
# │ sal      ┆ hydro_compartment_v001 ┆ annual    ┆ 500            ┆ … ┆ 0.2291 ┆ 0.0  ┆ 0.0  ┆ 0.0  │
# │ sal      ┆ hydro_compartment_v001 ┆ annual    ┆ 500            ┆ … ┆ 0.1419 ┆ 0.0  ┆ 0.0  ┆ 0.0  │
# │ sal      ┆ hydro_compartment_v001 ┆ annual    ┆ 500            ┆ … ┆ 0.4668 ┆ 0.0  ┆ 0.0  ┆ 0.0  │
# ...

# %%
lf = read_data(variable="ffibs_coverage_ratio", grid="veg_grid_cell_v001", time_unit="annual", model_group_id=500, scenario_id=7)
lf.collect()
# lf.collect()["path"][1]
# Out:
# shape: (312, 8)
# ┌────────────┬────────────┬───────────┬────────────┬───────────┬───────────┬───────────┬───────────┐
# │ variable   ┆ grid       ┆ time_unit ┆ model_grou ┆ scenario_ ┆ ffibs_typ ┆ calendar_ ┆ path      │
# │ ---        ┆ ---        ┆ ---       ┆ p_id       ┆ id        ┆ e         ┆ year      ┆ ---       │
# │ str        ┆ str        ┆ str       ┆ ---        ┆ ---       ┆ ---       ┆ ---       ┆ str       │
# │            ┆            ┆           ┆ i32        ┆ i32       ┆ str       ┆ i32       ┆           │
# ╞════════════╪════════════╪═══════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ ffibs_cove ┆ veg_grid_c ┆ annual    ┆ 500        ┆ 7         ┆ pl_bf     ┆ 2019      ┆ /ocean/pr │
# │ rage_ratio ┆ ell_v001   ┆           ┆            ┆           ┆           ┆           ┆ ojects/bc │
# │            ┆            ┆           ┆            ┆           ┆           ┆           ┆ s200002p/ │
# ...

# %%
# %connect_info
# Out:
# {
#   "shell_port": 57171,
#   "iopub_port": 56629,
#   "stdin_port": 48187,
#   "control_port": 51109,
#   "hb_port": 36341,
#   "ip": "127.0.0.1",
#   "key": "6aaa8b5c-1757f4d4c805b39f6fd150bb",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": "cpra",
#   "jupyter_session": "/jet/home/hjaehn/jupyter/read_data_example.ipynb"
# }
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-f738f3cf-3c97-4164-afa7-0886e768eb22.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.

# %%
import sys
print("Current Python executable:", sys.executable)
print("Python version:", sys.version)
# Out:
# Current Python executable: /opt/conda/bin/python3
# Python version: 3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:45:31) [GCC 13.3.0]

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# affine                    2.4.0
# alembic                   1.16.4
# altair                    5.5.0
# annotated-types           0.7.0
# anyio                     4.10.0
# archspec                  0.2.5
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async_generator           1.10
# async-lru                 2.0.5
# attrs                     25.3.0
# babel                     2.17.0
# beautifulsoup4            4.13.4
# bleach                    6.2.0
# blinker                   1.9.0
# bokeh                     3.7.3
# boltons                   25.0.0
# Bottleneck                1.5.0
# Brotli                    1.1.0
# cached-property           1.5.2
# cachetools                6.2.1
# certifi                   2025.8.3
# certipy                   0.2.2
# cffi                      1.17.1
# ...
